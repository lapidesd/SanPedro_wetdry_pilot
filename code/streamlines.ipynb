# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import geopandas as gpd
# %config InlineBackend.figure_format='retina'

# %%
MERIT = gpd.read_file('../data/MERIT_hydro_lines.shp')

# %%
MERIT = MERIT.explode()
MERIT['x'] = [MERIT.geometry.values[i].coords[0][0] for i in range(len(MERIT))]
MERIT['y'] = [MERIT.geometry.values[i].coords[0][1] for i in range(len(MERIT))]
# Out:
# /var/folders/9h/qhym8j_x3vlby3c3j9klp0vc0000gn/T/ipykernel_38727/1444494708.py:1: FutureWarning: Currently, index_parts defaults to True, but in the future, it will default to False to be consistent with Pandas. Use `index_parts=True` to keep the current behavior and True/False to silence the warning.
#   MERIT = MERIT.explode()

# %%
MERIT[(MERIT.y>31) & (MERIT.y<32.5) & (MERIT.x<-109) & (MERIT.x>-111)].to_file('../data/MERIT_Ramsey.shp',format='shp')

# %%
MERIT.x.hist()
# Out:
# <AxesSubplot:>

# %%
from pyPRISMClimate import get_prism_monthlys, get_prism_monthly_single, \
                    get_prism_dailys, get_prism_daily_single,\
                    get_prism_normals
